# %% [markdown]
# # Tensorflow 2.0 Keras Sagemaker
# From
# https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker-python-sdk/tensorflow_script_mode_training_and_serving/tensorflow_script_mode_training_and_serving.ipynb

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
region = sagemaker_session.boto_session.region_name

# %%
training_data_uri = 's3://sagemaker-sample-data-{}/tensorflow/mnist'.format(region)

# %%
# !pygmentize 'mnist-2.py'
# Out:
# # Copyright 2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License"). You
# # may not use this file except in compliance with the License. A copy of
# # the License is located at
# #
# #     http://aws.amazon.com/apache2.0/
# #
# # or in the "license" file accompanying this file. This file is
# # distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF
# # ANY KIND, either express or implied. See the License for the specific
# # language governing permissions and limitations under the License.import tensorflow as tf
#
# import tensorflow as tf
# import argparse
# import os
# import numpy as np
# import json
#
#
# def model(x_train, y_train, x_test, y_test):
#     """Generate a simple model"""
#     model = tf.keras.models.Sequential([
#         tf.keras.layers.Flatten(),
#         tf.keras.layers.Dense(1024, activation=tf.nn.relu),
#         tf.keras.layers.Dropout(0.4),
#         tf.keras.layers.Dense(10, activation=tf.nn.softmax)
#     ])
#
#     model.compile(optimizer='adam',
#                   loss='sparse_categorical_crossentropy',
#                   metrics=['accuracy'])
#     model.fit(x_train, y_train)
#     model.evaluate(x_test, y_test)
#
#     return model
#
#
# def _load_training_data(base_dir):
#     """Load MNIST training data"""
#     x_train = np.load(os.path.join(base_dir, 'train_data.npy'))
#     y_train = np.load(os.path.join(base_dir, 'train_labels.npy'))
#     return x_train, y_train
#
#
# def _load_testing_data(base_dir):
#     """Load MNIST testing data"""
#     x_test = np.load(os.path.join(base_dir, 'eval_data.npy'))
#     y_test = np.load(os.path.join(base_dir, 'eval_labels.npy'))
#     return x_test, y_test
#
#
# def _parse_args():
#     parser = argparse.ArgumentParser()
#
#     # Data, model, and output directories
#     # model_dir is always passed in from SageMaker. By default this is a S3 path under the default bucket.
#     parser.add_argument('--model_dir', type=str)
#     parser.add_argument('--sm-model-dir', type=str, default=os.environ.get('SM_MODEL_DIR'))
#     parser.add_argument('--train', type=str, default=os.environ.get('SM_CHANNEL_TRAINING'))
#     parser.add_argument('--hosts', type=list, default=json.loads(os.environ.get('SM_HOSTS')))
#     parser.add_argument('--current-host', type=str, default=os.environ.get('SM_CURRENT_HOST'))
#
#     return parser.parse_known_args()
#
#
# if __name__ == "__main__":
#     args, unknown = _parse_args()
#
#     train_data, train_labels = _load_training_data(args.train)
#     eval_data, eval_labels = _load_testing_data(args.train)
#
#     mnist_classifier = model(train_data, train_labels, eval_data, eval_labels)
#
#     if args.current_host == args.hosts[0]:
#         # save model to an S3 directory with version number '00000001'
#         mnist_classifier.save(os.path.join(args.sm_model_dir, '000000001'), 'my_model.h5')

# %%
from sagemaker.tensorflow import TensorFlow
mnist_estimator2 = TensorFlow(entry_point='mnist-2.py',
                             role=role,
                             train_instance_count=2,
                             train_instance_type='local',
                             framework_version='2.1.0',
                             py_version='py3',
                             distributions={'parameter_server': {'enabled': True}})

# %%
mnist_estimator2.fit(training_data_uri)
# Out:
# Creating tmpkovt6w3z_algo-2-y6ucy_1 ...
# Creating tmpkovt6w3z_algo-1-y6ucy_1 ...
# Attaching to tmpkovt6w3z_algo-2-y6ucy_1, tmpkovt6w3z_algo-1-y6ucy_1
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,479 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,487 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y6ucy_1  | 2020-07-03 16:26:12,554 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# algo-1-y6ucy_1  | 2020-07-03 16:26:12,562 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,624 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,625 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,625 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,649 sagemaker_tensorflow_container.training INFO     Launching worker process
# algo-1-y6ucy_1  | 2020-07-03 16:26:12,688 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# algo-1-y6ucy_1  | 2020-07-03 16:26:12,688 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# algo-1-y6ucy_1  | 2020-07-03 16:26:12,688 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# algo-1-y6ucy_1  | 2020-07-03 16:26:12,715 sagemaker_tensorflow_container.training INFO     Launching worker process
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,942 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,965 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-2-y6ucy_1  | 2020-07-03 16:26:12,987 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-2-y6ucy_1  | 2020-07-03 16:26:13,000 sagemaker-containers INFO     Invoking user script
# algo-2-y6ucy_1  |
# algo-2-y6ucy_1  | Training Env:
# algo-2-y6ucy_1  |
# algo-2-y6ucy_1  | {
# algo-2-y6ucy_1  |     "additional_framework_parameters": {
# algo-2-y6ucy_1  |         "sagemaker_parameter_server_enabled": true
# algo-2-y6ucy_1  |     },
# algo-2-y6ucy_1  |     "channel_input_dirs": {
# algo-2-y6ucy_1  |         "training": "/opt/ml/input/data/training"
# algo-2-y6ucy_1  |     },
# algo-2-y6ucy_1  |     "current_host": "algo-2-y6ucy",
# algo-2-y6ucy_1  |     "framework_module": "sagemaker_tensorflow_container.training:main",
# algo-2-y6ucy_1  |     "hosts": [
# algo-2-y6ucy_1  |         "algo-1-y6ucy",
# algo-2-y6ucy_1  |         "algo-2-y6ucy"
# algo-2-y6ucy_1  |     ],
# algo-2-y6ucy_1  |     "hyperparameters": {
# algo-2-y6ucy_1  |         "model_dir": "s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"
# algo-2-y6ucy_1  |     },
# algo-2-y6ucy_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-2-y6ucy_1  |     "input_data_config": {
# algo-2-y6ucy_1  |         "training": {
# algo-2-y6ucy_1  |             "TrainingInputMode": "File"
# algo-2-y6ucy_1  |         }
# algo-2-y6ucy_1  |     },
# algo-2-y6ucy_1  |     "input_dir": "/opt/ml/input",
# algo-2-y6ucy_1  |     "is_master": false,
# algo-2-y6ucy_1  |     "job_name": "tensorflow-training-2020-07-03-16-25-12-440",
# algo-2-y6ucy_1  |     "log_level": 20,
# algo-2-y6ucy_1  |     "master_hostname": "algo-1-y6ucy",
# algo-2-y6ucy_1  |     "model_dir": "/opt/ml/model",
# algo-2-y6ucy_1  |     "module_dir": "s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/source/sourcedir.tar.gz",
# algo-2-y6ucy_1  |     "module_name": "mnist-2",
# algo-2-y6ucy_1  |     "network_interface_name": "eth0",
# algo-2-y6ucy_1  |     "num_cpus": 2,
# algo-2-y6ucy_1  |     "num_gpus": 0,
# algo-2-y6ucy_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-2-y6ucy_1  |     "output_dir": "/opt/ml/output",
# algo-2-y6ucy_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-2-y6ucy_1  |     "resource_config": {
# algo-2-y6ucy_1  |         "current_host": "algo-2-y6ucy",
# algo-2-y6ucy_1  |         "hosts": [
# algo-2-y6ucy_1  |             "algo-1-y6ucy",
# algo-2-y6ucy_1  |             "algo-2-y6ucy"
# algo-2-y6ucy_1  |         ]
# algo-2-y6ucy_1  |     },
# algo-2-y6ucy_1  |     "user_entry_point": "mnist-2.py"
# algo-2-y6ucy_1  | }
# algo-2-y6ucy_1  |
# algo-2-y6ucy_1  | Environment variables:
# algo-2-y6ucy_1  |
# algo-2-y6ucy_1  | SM_HOSTS=["algo-1-y6ucy","algo-2-y6ucy"]
# algo-2-y6ucy_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-2-y6ucy_1  | SM_HPS={"model_dir":"s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"}
# algo-2-y6ucy_1  | SM_USER_ENTRY_POINT=mnist-2.py
# algo-2-y6ucy_1  | SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# algo-2-y6ucy_1  | SM_RESOURCE_CONFIG={"current_host":"algo-2-y6ucy","hosts":["algo-1-y6ucy","algo-2-y6ucy"]}
# algo-2-y6ucy_1  | SM_INPUT_DATA_CONFIG={"training":{"TrainingInputMode":"File"}}
# algo-2-y6ucy_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-2-y6ucy_1  | SM_CHANNELS=["training"]
# algo-2-y6ucy_1  | SM_CURRENT_HOST=algo-2-y6ucy
# algo-2-y6ucy_1  | SM_MODULE_NAME=mnist-2
# algo-2-y6ucy_1  | SM_LOG_LEVEL=20
# algo-2-y6ucy_1  | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# algo-2-y6ucy_1  | SM_INPUT_DIR=/opt/ml/input
# algo-2-y6ucy_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-2-y6ucy_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-2-y6ucy_1  | SM_NUM_CPUS=2
# algo-2-y6ucy_1  | SM_NUM_GPUS=0
# algo-2-y6ucy_1  | SM_MODEL_DIR=/opt/ml/model
# algo-2-y6ucy_1  | SM_MODULE_DIR=s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/source/sourcedir.tar.gz
# algo-2-y6ucy_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2-y6ucy","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-y6ucy","algo-2-y6ucy"],"hyperparameters":{"model_dir":"s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"tensorflow-training-2020-07-03-16-25-12-440","log_level":20,"master_hostname":"algo-1-y6ucy","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/source/sourcedir.tar.gz","module_name":"mnist-2","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2-y6ucy","hosts":["algo-1-y6ucy","algo-2-y6ucy"]},"user_entry_point":"mnist-2.py"}
# algo-2-y6ucy_1  | SM_USER_ARGS=["--model_dir","s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"]
# algo-2-y6ucy_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-2-y6ucy_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-2-y6ucy_1  | SM_HP_MODEL_DIR=s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model
# algo-2-y6ucy_1  | TF_CONFIG={"cluster": {"master": ["algo-1-y6ucy:2222"], "ps": ["algo-1-y6ucy:2223", "algo-2-y6ucy:2223"], "worker": ["algo-2-y6ucy:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# algo-2-y6ucy_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-2-y6ucy_1  |
# algo-2-y6ucy_1  | Invoking script with the following command:
# algo-2-y6ucy_1  |
# algo-2-y6ucy_1  | /usr/bin/python3 mnist-2.py --model_dir s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model
# algo-2-y6ucy_1  |
# algo-2-y6ucy_1  |
# algo-1-y6ucy_1  | 2020-07-03 16:26:13,014 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y6ucy_1  | 2020-07-03 16:26:13,038 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y6ucy_1  | 2020-07-03 16:26:13,063 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# algo-1-y6ucy_1  | 2020-07-03 16:26:13,076 sagemaker-containers INFO     Invoking user script
# algo-1-y6ucy_1  |
# algo-1-y6ucy_1  | Training Env:
# algo-1-y6ucy_1  |
# algo-1-y6ucy_1  | {
# algo-1-y6ucy_1  |     "additional_framework_parameters": {
# algo-1-y6ucy_1  |         "sagemaker_parameter_server_enabled": true
# algo-1-y6ucy_1  |     },
# algo-1-y6ucy_1  |     "channel_input_dirs": {
# algo-1-y6ucy_1  |         "training": "/opt/ml/input/data/training"
# algo-1-y6ucy_1  |     },
# algo-1-y6ucy_1  |     "current_host": "algo-1-y6ucy",
# algo-1-y6ucy_1  |     "framework_module": "sagemaker_tensorflow_container.training:main",
# algo-1-y6ucy_1  |     "hosts": [
# algo-1-y6ucy_1  |         "algo-1-y6ucy",
# algo-1-y6ucy_1  |         "algo-2-y6ucy"
# algo-1-y6ucy_1  |     ],
# algo-1-y6ucy_1  |     "hyperparameters": {
# algo-1-y6ucy_1  |         "model_dir": "s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"
# algo-1-y6ucy_1  |     },
# algo-1-y6ucy_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-y6ucy_1  |     "input_data_config": {
# algo-1-y6ucy_1  |         "training": {
# algo-1-y6ucy_1  |             "TrainingInputMode": "File"
# algo-1-y6ucy_1  |         }
# algo-1-y6ucy_1  |     },
# algo-1-y6ucy_1  |     "input_dir": "/opt/ml/input",
# algo-1-y6ucy_1  |     "is_master": true,
# algo-1-y6ucy_1  |     "job_name": "tensorflow-training-2020-07-03-16-25-12-440",
# algo-1-y6ucy_1  |     "log_level": 20,
# algo-1-y6ucy_1  |     "master_hostname": "algo-1-y6ucy",
# algo-1-y6ucy_1  |     "model_dir": "/opt/ml/model",
# algo-1-y6ucy_1  |     "module_dir": "s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/source/sourcedir.tar.gz",
# algo-1-y6ucy_1  |     "module_name": "mnist-2",
# algo-1-y6ucy_1  |     "network_interface_name": "eth0",
# algo-1-y6ucy_1  |     "num_cpus": 2,
# algo-1-y6ucy_1  |     "num_gpus": 0,
# algo-1-y6ucy_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-y6ucy_1  |     "output_dir": "/opt/ml/output",
# algo-1-y6ucy_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-y6ucy_1  |     "resource_config": {
# algo-1-y6ucy_1  |         "current_host": "algo-1-y6ucy",
# algo-1-y6ucy_1  |         "hosts": [
# algo-1-y6ucy_1  |             "algo-1-y6ucy",
# algo-1-y6ucy_1  |             "algo-2-y6ucy"
# algo-1-y6ucy_1  |         ]
# algo-1-y6ucy_1  |     },
# algo-1-y6ucy_1  |     "user_entry_point": "mnist-2.py"
# algo-1-y6ucy_1  | }
# algo-1-y6ucy_1  |
# algo-1-y6ucy_1  | Environment variables:
# algo-1-y6ucy_1  |
# algo-1-y6ucy_1  | SM_HOSTS=["algo-1-y6ucy","algo-2-y6ucy"]
# algo-1-y6ucy_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-y6ucy_1  | SM_HPS={"model_dir":"s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"}
# algo-1-y6ucy_1  | SM_USER_ENTRY_POINT=mnist-2.py
# algo-1-y6ucy_1  | SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# algo-1-y6ucy_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-y6ucy","hosts":["algo-1-y6ucy","algo-2-y6ucy"]}
# algo-1-y6ucy_1  | SM_INPUT_DATA_CONFIG={"training":{"TrainingInputMode":"File"}}
# algo-1-y6ucy_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-y6ucy_1  | SM_CHANNELS=["training"]
# algo-1-y6ucy_1  | SM_CURRENT_HOST=algo-1-y6ucy
# algo-1-y6ucy_1  | SM_MODULE_NAME=mnist-2
# algo-1-y6ucy_1  | SM_LOG_LEVEL=20
# algo-1-y6ucy_1  | SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# algo-1-y6ucy_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-y6ucy_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-y6ucy_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-y6ucy_1  | SM_NUM_CPUS=2
# algo-1-y6ucy_1  | SM_NUM_GPUS=0
# algo-1-y6ucy_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-y6ucy_1  | SM_MODULE_DIR=s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/source/sourcedir.tar.gz
# algo-1-y6ucy_1  | SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1-y6ucy","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1-y6ucy","algo-2-y6ucy"],"hyperparameters":{"model_dir":"s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2020-07-03-16-25-12-440","log_level":20,"master_hostname":"algo-1-y6ucy","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/source/sourcedir.tar.gz","module_name":"mnist-2","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-y6ucy","hosts":["algo-1-y6ucy","algo-2-y6ucy"]},"user_entry_point":"mnist-2.py"}
# algo-1-y6ucy_1  | SM_USER_ARGS=["--model_dir","s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model"]
# algo-1-y6ucy_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-y6ucy_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-y6ucy_1  | SM_HP_MODEL_DIR=s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model
# algo-1-y6ucy_1  | TF_CONFIG={"cluster": {"master": ["algo-1-y6ucy:2222"], "ps": ["algo-1-y6ucy:2223", "algo-2-y6ucy:2223"], "worker": ["algo-2-y6ucy:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# algo-1-y6ucy_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
# algo-1-y6ucy_1  |
# algo-1-y6ucy_1  | Invoking script with the following command:
# algo-1-y6ucy_1  |
# algo-1-y6ucy_1  | /usr/bin/python3 mnist-2.py --model_dir s3://sagemaker-us-east-2-483146584438/tensorflow-training-2020-07-03-16-25-12-440/model
# algo-1-y6ucy_1  |
# algo-1-y6ucy_1  |
# algo-2-y6ucy_1  | Train on 55000 samples
# algo-1-y6ucy_1  | Train on 55000 samples
# 55000/55000 [==============================] - 17s 311us/sample - loss: 0.2348 - accuracy: 0.9294
# 55000/55000 [==============================] - 18s 319us/sample - loss: 0.2349 - accuracy: 0.9306
# 10000/10000 [==============================] - 1s 147us/sample - loss: 0.1052 - accuracy: 0.9686
# algo-2-y6ucy_1  | 2020-07-03 16:26:37,175 sagemaker_tensorflow_container.training INFO     master algo-1-y6ucy is down, stopping parameter server
# algo-2-y6ucy_1  | 2020-07-03 16:26:37,176 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# algo-2-y6ucy_1  | For details of how to construct your training script see:
# algo-2-y6ucy_1  | https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# algo-2-y6ucy_1  | 2020-07-03 16:26:37,177 sagemaker-containers INFO     Reporting training SUCCESS
# 10000/10000 [==============================] - 1s 150us/sample - loss: 0.1100 - accuracy: 0.9636
# tmpkovt6w3z_algo-2-y6ucy_1 exited with code 0
# Stopping tmpkovt6w3z_algo-1-y6ucy_1 ...
# Aborting on container exit..._1 ... done
# ===== Job Complete =====
